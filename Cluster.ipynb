# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\Study\BA\TEST\Cluster\CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.nunique()
# Out:
# CUST_ID                             8950
# BALANCE                             8871
# BALANCE_FREQUENCY                     43
# PURCHASES                           6203
# ONEOFF_PURCHASES                    4014
# INSTALLMENTS_PURCHASES              4452
# CASH_ADVANCE                        4323
# PURCHASES_FREQUENCY                   47
# ONEOFF_PURCHASES_FREQUENCY            47
# PURCHASES_INSTALLMENTS_FREQUENCY      47
# CASH_ADVANCE_FREQUENCY                54
# CASH_ADVANCE_TRX                      65
# PURCHASES_TRX                        173
# CREDIT_LIMIT                         205
# PAYMENTS                            8711
# MINIMUM_PAYMENTS                    8636
# PRC_FULL_PAYMENT                      47
# TENURE                                 7
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.CREDIT_LIMIT = df.CREDIT_LIMIT.fillna(4494.449450)

# %%
df.MINIMUM_PAYMENTS = df.MINIMUM_PAYMENTS.fillna(864.206542)

# %%
df.boxplot(figsize=(40,10))

# %%
df = df.drop(['CUST_ID'],axis=1)

# %%
min=df['BALANCE'].quantile(0.05)
max=df['BALANCE'].quantile(0.90)
new=np.where(df['BALANCE']<min,min,df['BALANCE'])
df.BALANCE=new
new=np.where(df['BALANCE']>max,max,df['BALANCE'])
df.BALANCE=new

# %%
df.boxplot('BALANCE_FREQUENCY')

# %%
min=df['BALANCE_FREQUENCY'].quantile(0.18)
max=df['BALANCE_FREQUENCY'].quantile(0.95)
new=np.where(df['BALANCE_FREQUENCY']<min,min,df['BALANCE_FREQUENCY'])
df.BALANCE_FREQUENCY=new
new=np.where(df['BALANCE_FREQUENCY']>max,max,df['BALANCE_FREQUENCY'])
df.BALANCE_FREQUENCY=new

# %%
df.boxplot('PURCHASES')

# %%
min=df['PURCHASES'].quantile(0.05)
max=df['PURCHASES'].quantile(0.90)
new=np.where(df['PURCHASES']<min,min,df['PURCHASES'])
df.PURCHASES=new
new=np.where(df['PURCHASES']>max,max,df['PURCHASES'])
df.PURCHASES=new

# %%
df.boxplot('ONEOFF_PURCHASES')

# %%
min=df['ONEOFF_PURCHASES'].quantile(0.05)
max=df['ONEOFF_PURCHASES'].quantile(0.88)
new=np.where(df['ONEOFF_PURCHASES']<min,min,df['ONEOFF_PURCHASES'])
df.ONEOFF_PURCHASES=new
new=np.where(df['ONEOFF_PURCHASES']>max,max,df['ONEOFF_PURCHASES'])
df.ONEOFF_PURCHASES=new

# %%
df.boxplot('INSTALLMENTS_PURCHASES')

# %%
min=df['INSTALLMENTS_PURCHASES'].quantile(0.05)
max=df['INSTALLMENTS_PURCHASES'].quantile(0.90)
new=np.where(df['INSTALLMENTS_PURCHASES']<min,min,df['INSTALLMENTS_PURCHASES'])
df.INSTALLMENTS_PURCHASES=new
new=np.where(df['INSTALLMENTS_PURCHASES']>max,max,df['INSTALLMENTS_PURCHASES'])
df.INSTALLMENTS_PURCHASES=new

# %%
df.boxplot('CASH_ADVANCE')

# %%
min=df['CASH_ADVANCE'].quantile(0.05)
max=df['CASH_ADVANCE'].quantile(0.88)
new=np.where(df['CASH_ADVANCE']<min,min,df['CASH_ADVANCE'])
df.CASH_ADVANCE=new
new=np.where(df['CASH_ADVANCE']>max,max,df['CASH_ADVANCE'])
df.CASH_ADVANCE=new

# %%
df.boxplot("ONEOFF_PURCHASES_FREQUENCY")

# %%
min=df['ONEOFF_PURCHASES_FREQUENCY'].quantile(0.05)
max=df['ONEOFF_PURCHASES_FREQUENCY'].quantile(0.90)
new=np.where(df['ONEOFF_PURCHASES_FREQUENCY']<min,min,df['ONEOFF_PURCHASES_FREQUENCY'])
df.ONEOFF_PURCHASES_FREQUENCY=new
new=np.where(df['ONEOFF_PURCHASES_FREQUENCY']>max,max,df['ONEOFF_PURCHASES_FREQUENCY'])
df.ONEOFF_PURCHASES_FREQUENCY=new

# %%
df.boxplot("CASH_ADVANCE_FREQUENCY")

# %%
min=df['CASH_ADVANCE_FREQUENCY'].quantile(0.05)
max=df['CASH_ADVANCE_FREQUENCY'].quantile(0.90)
new=np.where(df['CASH_ADVANCE_FREQUENCY']<min,min,df['CASH_ADVANCE_FREQUENCY'])
df.CASH_ADVANCE_FREQUENCY=new
new=np.where(df['CASH_ADVANCE_FREQUENCY']>max,max,df['CASH_ADVANCE_FREQUENCY'])
df.CASH_ADVANCE_FREQUENCY=new

# %%
df.boxplot("CASH_ADVANCE_TRX")

# %%
min=df['CASH_ADVANCE_TRX'].quantile(0.05)
max=df['CASH_ADVANCE_TRX'].quantile(0.90)
new=np.where(df['CASH_ADVANCE_TRX']<min,min,df['CASH_ADVANCE_TRX'])
df.CASH_ADVANCE_TRX=new
new=np.where(df['CASH_ADVANCE_TRX']>max,max,df['CASH_ADVANCE_TRX'])
df.CASH_ADVANCE_TRX=new

# %%
df.boxplot("PURCHASES_TRX")

# %%
min=df['PURCHASES_TRX'].quantile(0.05)
max=df['PURCHASES_TRX'].quantile(0.90)
new=np.where(df['PURCHASES_TRX']<min,min,df['PURCHASES_TRX'])
df.PURCHASES_TRX=new
new=np.where(df['PURCHASES_TRX']>max,max,df['PURCHASES_TRX'])
df.PURCHASES_TRX=new

# %%
df.boxplot("CREDIT_LIMIT")

# %%
min=df['CREDIT_LIMIT'].quantile(0.05)
max=df['CREDIT_LIMIT'].quantile(0.95)
new=np.where(df['CREDIT_LIMIT']<min,min,df['CREDIT_LIMIT'])
df.CREDIT_LIMIT=new
new=np.where(df['CREDIT_LIMIT']>max,max,df['CREDIT_LIMIT'])
df.CREDIT_LIMIT=new

# %%
df.boxplot("PAYMENTS")

# %%
min=df['PAYMENTS'].quantile(0.05)
max=df['PAYMENTS'].quantile(0.90)
new=np.where(df['PAYMENTS']<min,min,df['PAYMENTS'])
df.PAYMENTS=new
new=np.where(df['PAYMENTS']>max,max,df['PAYMENTS'])
df.PAYMENTS=new

# %%
df.boxplot("MINIMUM_PAYMENTS")

# %%
min=df['MINIMUM_PAYMENTS'].quantile(0.05)
max=df['MINIMUM_PAYMENTS'].quantile(0.90)
new=np.where(df['MINIMUM_PAYMENTS']<min,min,df['MINIMUM_PAYMENTS'])
df.MINIMUM_PAYMENTS=new
new=np.where(df['MINIMUM_PAYMENTS']>max,max,df['MINIMUM_PAYMENTS'])
df.MINIMUM_PAYMENTS=new

# %%
df.boxplot("PRC_FULL_PAYMENT")

# %%
min=df['PRC_FULL_PAYMENT'].quantile(0.05)
max=df['PRC_FULL_PAYMENT'].quantile(0.82)
new=np.where(df['PRC_FULL_PAYMENT']<min,min,df['PRC_FULL_PAYMENT'])
df.PRC_FULL_PAYMENT=new
new=np.where(df['PRC_FULL_PAYMENT']>max,max,df['PRC_FULL_PAYMENT'])
df.PRC_FULL_PAYMENT=new

# %%
df.boxplot("TENURE")

# %%
df.boxplot(figsize=(30,8))

# %%
corr = df.corr()
plt.subplots(figsize = (30,10))
sns.heatmap(corr,annot=True)

# %%
df.all()
# Out:
# BALANCE                              True
# BALANCE_FREQUENCY                    True
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                         True
# PAYMENTS                             True
# MINIMUM_PAYMENTS                     True
# PRC_FULL_PAYMENT                    False
# TENURE                               True
# dtype: bool

# %%
newdata = df.drop(['BALANCE_FREQUENCY','ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES','CASH_ADVANCE','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY','PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY','CASH_ADVANCE_TRX','PURCHASES_TRX','MINIMUM_PAYMENTS','PRC_FULL_PAYMENT'],axis=1)

# %%
from sklearn.cluster import KMeans

# %%
K = range(1, 30)

# %%
Sum_of_squared_distances = []
for k in K:
    km = KMeans(n_clusters=k, random_state=0)
    km = km.fit(newdata)
    Sum_of_squared_distances.append(km.inertia_)

plt.plot(K, Sum_of_squared_distances)
plt.show()

# %%
K = 4

# %%
clustering = KMeans(n_clusters=K,random_state=0)
finalcluster = clustering.fit_predict(newdata)

# %%
plt.hist(finalcluster, bins=range(K+2))
# Out:
# (array([5088., 1119., 1569., 1174.,    0.]),
#  array([0, 1, 2, 3, 4, 5]),
#  <a list of 5 Patch objects>)

# %%
newdata[km.labels_==0]
# Out:
#           BALANCE  PURCHASES  CREDIT_LIMIT    PAYMENTS  TENURE
# 4      817.714335      16.00        1200.0  678.334763      12
# 20    2016.684686     176.68        2000.0  223.068600      12
# 26    1615.967240     102.00        1700.0  890.178845      12
# 35    1656.350781       0.00        1800.0  351.500199      12
# 43    1360.742377       0.00        1500.0  378.294227      12
# ...           ...        ...           ...         ...     ...
# 8873  1023.883008     585.84        1000.0  212.105443       8
# 8878   869.328293       0.00        1200.0  150.755024       8
# 8895   893.949463     958.80        1200.0  590.785658       7
# 8896  1117.594403     291.62        2000.0   89.988924       7
# 8920  1055.087681       0.00        2000.0   89.988924       6
#
# [983 rows x 5 columns]

# %%
newdata[km.labels_==1]
# Out:
#           BALANCE  PURCHASES  CREDIT_LIMIT     PAYMENTS  TENURE
# 2     2495.148862     773.17        7500.0   622.066742      12
# 3     1666.670542    1499.00        7500.0    89.988924      12
# 96    1619.955708     739.44        6000.0   417.128532      12
# 145   3057.400553    1025.00        7500.0   698.854095      12
# 186   1706.014379     147.78        6000.0  1186.062765      12
# ...           ...        ...           ...          ...     ...
# 8089  2784.030599    1470.00        7000.0   745.850159      11
# 8150  2495.255050      89.90        6000.0   582.339752      11
# 8181  1606.875936    1863.48        6500.0   698.650140      12
# 8371  2579.635387       0.00        7000.0  1415.843333      11
# 8597  2601.463574       0.00        6000.0  1317.570981      12
#
# [212 rows x 5 columns]

# %%
newdata[km.labels_==2]
# Out:
#           BALANCE  PURCHASES  CREDIT_LIMIT     PAYMENTS  TENURE
# 68    3990.523579     263.50        6000.0  3923.906642      12
# 182   2881.253586     117.00        4500.0  3923.906642      12
# 199   4338.563657      47.55        6000.0  2976.579866      12
# 408   3024.629054       0.00        4500.0  3923.906642      12
# 431   4245.550244     332.82        5000.0  3923.906642      12
# ...           ...        ...           ...          ...     ...
# 7549  3025.373271     202.72        4500.0  3923.906642      12
# 7649  3495.735827       0.00        5000.0  3923.906642      12
# 8119  3278.982195       0.00        4500.0  3810.096650      12
# 8315  2648.244646       0.00        4000.0  3923.906642      12
# 8503  3074.490820       0.00        4000.0  3249.404994      12
#
# [88 rows x 5 columns]

# %%
newdata[km.labels_==3]
# Out:
#           BALANCE  PURCHASES  CREDIT_LIMIT     PAYMENTS  TENURE
# 5     1809.828751   1333.280        1800.0  1400.057770      12
# 10    1293.124939    920.120        1200.0  1083.301007      12
# 11     630.794744   1492.180        2000.0   705.618627      12
# 51    1078.888565   2542.624        2500.0  1399.828340      12
# 69    1699.435486   1363.690        1700.0  1623.816348      12
# ...           ...        ...           ...          ...     ...
# 8847   224.692470   1112.070        1500.0   900.366427       9
# 8856   227.220411   1387.600        1000.0  1217.473837       8
# 8883   931.907808   1142.120        1000.0   957.421268       7
# 8897   328.686581   2542.624        1200.0  1796.886852       7
# 8923   486.661842   1898.880        1200.0   669.039640       6
#
# [383 rows x 5 columns]
